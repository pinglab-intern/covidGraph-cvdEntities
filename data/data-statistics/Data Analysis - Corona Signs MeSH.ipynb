# %% [markdown]
# ### Data Stat
#
# This notebook sumarizes the preliminary data found in Corona virus, Covid-19 document count, time published, cohort studied etc.

# %%
import json as json

# %%
with open("corona_signs_id2name.json",'r')as rf:
    id2name = json.load(rf)

# %%
DATA = []
with open("../mesh_search/mesh_corona_signs_paper_ids.json", 'r') as fcount:
        data = json.load(fcount)
        for key,value in data.items():
            DATA.append({"MeSH":key,"Count":len(value)})

# %%
DATA
# Out:
# [{'Count': 834, 'MeSH': 'C01.748.561'},
#  {'Count': 937, 'MeSH': 'C01.757.800'},
#  {'Count': 1670, 'MeSH': 'C05.651.542'},
#  {'Count': 387, 'MeSH': 'C06.552.308.500'},
#  {'Count': 834, 'MeSH': 'C07.550.781'},
#  {'Count': 328, 'MeSH': 'C08.381.348'},
#  {'Count': 752, 'MeSH': 'C08.381.742'},
#  {'Count': 6228, 'MeSH': 'C08.618.248'},
#  {'Count': 1958, 'MeSH': 'C08.618.326'},
#  {'Count': 137, 'MeSH': 'C08.618.846'},
#  {'Count': 834, 'MeSH': 'C08.730.561'},
#  {'Count': 834, 'MeSH': 'C09.775.649'},
#  {'Count': 1355, 'MeSH': 'C10.597.606.337'},
#  {'Count': 0, 'MeSH': 'C10.597.751.600'},
#  {'Count': 1670, 'MeSH': 'C10.668.491.525'},
#  {'Count': 277, 'MeSH': 'C12.777.419.780.050'},
#  {'Count': 277, 'MeSH': 'C13.351.968.419.780.050'},
#  {'Count': 762, 'MeSH': 'C14.907.514'},
#  {'Count': 1044, 'MeSH': 'C15.378.553.546'},
#  {'Count': 794, 'MeSH': 'C15.378.553.546.184.564'},
#  {'Count': 328, 'MeSH': 'C23.550.414.896'},
#  {'Count': 937, 'MeSH': 'C23.550.470.790.500.800'},
#  {'Count': 310, 'MeSH': 'C23.550.835.525'},
#  {'Count': 937, 'MeSH': 'C23.550.835.900.712'},
#  {'Count': 11740, 'MeSH': 'C23.888.119.344'},
#  {'Count': 995, 'MeSH': 'C23.888.208'},
#  {'Count': 1677, 'MeSH': 'C23.888.369'},
#  {'Count': 1355, 'MeSH': 'C23.888.592.604.339'},
#  {'Count': 1092, 'MeSH': 'C23.888.592.612.054'},
#  {'Count': 694, 'MeSH': 'C23.888.592.612.233'},
#  {'Count': 2365, 'MeSH': 'C23.888.592.612.441'},
#  {'Count': 1670, 'MeSH': 'C23.888.592.612.547.249'},
#  {'Count': 349, 'MeSH': 'C23.888.592.763.237'},
#  {'Count': 0, 'MeSH': 'C23.888.592.763.550'},
#  {'Count': 1092, 'MeSH': 'C23.888.821.030'},
#  {'Count': 1593, 'MeSH': 'C23.888.821.108'},
#  {'Count': 5872, 'MeSH': 'C23.888.821.214'},
#  {'Count': 1406, 'MeSH': 'C23.888.821.712'},
#  {'Count': 2969, 'MeSH': 'C23.888.821.937'},
#  {'Count': 1289, 'MeSH': 'C23.888.852.079'},
#  {'Count': 6228, 'MeSH': 'C23.888.852.293'},
#  {'Count': 1958, 'MeSH': 'C23.888.852.371'},
#  {'Count': 328, 'MeSH': 'C23.888.852.430'},
#  {'Count': 1357, 'MeSH': 'C23.888.852.889'},
#  {'Count': 1355, 'MeSH': 'F01.700.250'},
#  {'Count': 1670, 'MeSH': 'F02.830.816.353.500'},
#  {'Count': 183, 'MeSH': 'G09.188.390.150'},
#  {'Count': 1357, 'MeSH': 'G09.772.832'},
#  {'Count': 1670, 'MeSH': 'G11.561.790.353.500'}]

# %%
import pandas as pd
DF = pd.DataFrame(DATA)

# %%
DF = DF.sort_values('Count', ascending =False)

# %%
DF
# Out:
#     Count                     MeSH
# 24  11740          C23.888.119.344
# 40   6228          C23.888.852.293
# 7    6228              C08.618.248
# 36   5872          C23.888.821.214
# 38   2969          C23.888.821.937
# 30   2365      C23.888.592.612.441
# 41   1958          C23.888.852.371
# 8    1958              C08.618.326
# 26   1677              C23.888.369
# 14   1670          C10.668.491.525
# 45   1670      F02.830.816.353.500
# 31   1670  C23.888.592.612.547.249
# 48   1670      G11.561.790.353.500
# 2    1670              C05.651.542
# 35   1593          C23.888.821.108
# 37   1406          C23.888.821.712
# 47   1357              G09.772.832
# 43   1357          C23.888.852.889
# 12   1355          C10.597.606.337
# 44   1355              F01.700.250
# 27   1355      C23.888.592.604.339
# 39   1289          C23.888.852.079
# 34   1092          C23.888.821.030
# 28   1092      C23.888.592.612.054
# 18   1044          C15.378.553.546
# 25    995              C23.888.208
# 23    937      C23.550.835.900.712
# 1     937              C01.757.800
# 21    937  C23.550.470.790.500.800
# 4     834              C07.550.781
# 0     834              C01.748.561
# 10    834              C08.730.561
# 11    834              C09.775.649
# 19    794  C15.378.553.546.184.564
# 17    762              C14.907.514
# 6     752              C08.381.742
# 29    694      C23.888.592.612.233
# 3     387          C06.552.308.500
# 32    349      C23.888.592.763.237
# 20    328          C23.550.414.896
# 5     328              C08.381.348
# 42    328          C23.888.852.430
# 22    310          C23.550.835.525
# 16    277  C13.351.968.419.780.050
# 15    277      C12.777.419.780.050
# 46    183          G09.188.390.150
# 9     137              C08.618.846
# 33      0      C23.888.592.763.550
# 13      0          C10.597.751.600

# %%
DF['Name'] = DF['MeSH'].apply(lambda x: id2name[x])

# %%
DF = DF.set_index('Name')

# %%
DF
# Out:
#                            Count                     MeSH
# Name
# Fever                      11740          C23.888.119.344
# Cough                       6228          C23.888.852.293
# Cough                       6228              C08.618.248
# Diarrhea                    5872          C23.888.821.214
# Vomiting                    2969          C23.888.821.937
# Headache                    2365      C23.888.592.612.441
# Dyspnea                     1958          C23.888.852.371
# Dyspnea                     1958              C08.618.326
# Fatigue                     1677              C23.888.369
# Myalgia                     1670          C10.668.491.525
# Myalgia                     1670      F02.830.816.353.500
# Myalgia                     1670  C23.888.592.612.547.249
# Myalgia                     1670      G11.561.790.353.500
# Myalgia                     1670              C05.651.542
# Anorexia                    1593          C23.888.821.108
# Nausea                      1406          C23.888.821.712
# Sneezing                    1357              G09.772.832
# Sneezing                    1357          C23.888.852.889
# Confusion                   1355          C10.597.606.337
# Confusion                   1355              F01.700.250
# Confusion                   1355      C23.888.592.604.339
# Hypoxia                     1289          C23.888.852.079
# Abdominal Pain              1092          C23.888.821.030
# Abdominal Pain              1092      C23.888.592.612.054
# Leukopenia                  1044          C15.378.553.546
# Chills                       995              C23.888.208
# Shock, Septic                937      C23.550.835.900.712
# Shock, Septic                937              C01.757.800
# Shock, Septic                937  C23.550.470.790.500.800
# Pharyngitis                  834              C07.550.781
# Pharyngitis                  834              C01.748.561
# Pharyngitis                  834              C08.730.561
# Pharyngitis                  834              C09.775.649
# Neutropenia                  794  C15.378.553.546.184.564
# Hypotension                  762              C14.907.514
# Pulmonary Edema              752              C08.381.742
# Chest Pain                   694      C23.888.592.612.233
# Liver Failure                387          C06.552.308.500
# Dizziness                    349      C23.888.592.763.237
# Hemoptysis                   328          C23.550.414.896
# Hemoptysis                   328              C08.381.348
# Hemoptysis                   328          C23.888.852.430
# Multiple Organ Failure       310          C23.550.835.525
# Acute Kidney Injury          277  C13.351.968.419.780.050
# Acute Kidney Injury          277      C12.777.419.780.050
# Blood Coagulation            183          G09.188.390.150
# Respiratory Insufficiency    137              C08.618.846
# Olfaction Disorders            0      C23.888.592.763.550
# Olfaction Disorders            0          C10.597.751.600

# %%
DF.to_csv('corona_signs_mesh_count.csv')

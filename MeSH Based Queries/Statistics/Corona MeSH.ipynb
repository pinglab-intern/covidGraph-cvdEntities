# %% [markdown]
# ## Data Analysis
#
# This notebook sumarizes the preliminary data found in Corona virus, Covid-19 document count, time published, cohort studied etc.

# %%
import json as json
import pandas as pd
from neo4j import GraphDatabase
import csv

# %%
covid_browser = "https://covid.petesis.com:7473"
covid_url = "bolt://covid.petesis.com:7687"
user = "public"
password = "corona"

driver = GraphDatabase.driver(uri = covid_url,\
                              auth = (user,password))

# %%
with open("../../Data/mesh/statistics/corona_id2name.json",'r')as rf:
    id2name = json.load(rf)

# %%
DATA = []
allIDs = []
with open("../../Data/mesh/corona_paper_ids.json", 'r') as fcount:
        data = json.load(fcount)
        for key,value in data.items():
            for xid in value:
                allIDs.append(xid)
            DATA.append({"MeSH":key,"Count":len(value)})

# %% [markdown]
# ### Document Count

# %%
DATA
# Out:
# [{'Count': 679, 'MeSH': 'C01.925.782.600.550.200'},
#  {'Count': 5, 'MeSH': 'C01.925.782.600.550.200.325'},
#  {'Count': 1045, 'MeSH': 'C01.925.782.600.550.200.360'},
#  {'Count': 153, 'MeSH': 'C01.925.782.600.550.200.400'},
#  {'Count': 12176, 'MeSH': 'C01.925.782.600.550.200.750'}]

# %%
DF = pd.DataFrame(DATA)

# %%
DF = DF.sort_values('Count', ascending =False)

# %%
DF
# Out:
#    Count                         MeSH
# 4  12176  C01.925.782.600.550.200.750
# 2   1045  C01.925.782.600.550.200.360
# 0    679      C01.925.782.600.550.200
# 3    153  C01.925.782.600.550.200.400
# 1      5  C01.925.782.600.550.200.325

# %%
DF['Name'] = DF['MeSH'].apply(lambda x: id2name[x])

# %%
DF = DF.set_index('Name')

# %%
DF
# Out:
#                                           Count                         MeSH
# Name
# Severe Acute Respiratory Syndrome         12176  C01.925.782.600.550.200.750
# Feline Infectious Peritonitis              1045  C01.925.782.600.550.200.360
# Coronavirus Infections                      679      C01.925.782.600.550.200
# Gastroenteritis, Transmissible, of Swine    153  C01.925.782.600.550.200.400
# Enteritis, Transmissible, of Turkeys          5  C01.925.782.600.550.200.325

# %%
DF.to_csv('corona_mesh_count.csv')

# %% [markdown]
# ### Cohort and Region

# %%
uniqueIDs = list(set(allIDs))
len(uniqueIDs)
# Out:
# 13357

# %%
PaperID_to_Info = []
limit = 0
for _id in uniqueIDs:
    paper_info = {}
    
    #Builds each part of the query based on the MeSH descriptor entity list
    query_info = "MATCH (p:Paper) WHERE p.cord_uid = '" + str(_id) + "' RETURN DISTINCT p"
    
    query_bodytext = "MATCH (p:Paper)-[:PAPER_HAS_BODYTEXTCOLLECTION]-(:BodyTextCollection)-" \
                        "[:BODYTEXTCOLLECTION_HAS_BODYTEXT]-(b:BodyText) WHERE p.cord_uid = '" \
                        + str(_id) + "' RETURN DISTINCT b"
            
    query_abstract = "MATCH (p:Paper)-[:PAPER_HAS_ABSTRACTCOLLECTION]-(:AbstractCollection)-" \
                        "[:ABSTRACTCOLLECTION_HAS_ABSTRACT]-(a:Abstract) WHERE p.cord_uid = '" \
                        + str(_id) + "' RETURN DISTINCT a"
    
    with driver.session() as session:
        info = session.run(query_info)
        for item in info:
            node_keys = list((item.values(0)[0]).keys())
            node_values = list((item.values(0)[0]).values())
            for i in range(len(node_keys)):
                paper_info[node_keys[i]] = node_values[i]
        
        bodytext = session.run(query_bodytext)
        bodytext_list = []
        for item in bodytext:
            try:
                node_keys = list((item.values(0)[0]).keys())
                node_values = list((item.values(0)[0]).values())
                for i in range(len(node_keys)):
                    if (node_keys[i] == '_hash_id'):
                        bodytext_list.append(node_values[i])
            except:
                continue
        paper_info['bodytexts'] = bodytext_list
        
        abstract = session.run(query_abstract)
        abstract_list = []
        for item in abstract:
            try:
                node_keys = list((item.values(0)[0]).keys())
                node_values = list((item.values(0)[0]).values())
                for i in range(len(node_keys)):
                    if (node_keys[i] == '_hash_id'):
                        abstract_list.append(node_values[i])  
            except:
                continue
        paper_info['abstracts'] = abstract_list
    
    try:
        PaperID_to_Info.append({"MeSH":_id, "Info":paper_info})
        if limit == 0:
            print(PaperID_to_Info)
    except:
        continue
    limit += 1
# Out:
# [{'MeSH': '0x9mjwpc', 'Info': {'cord_uid': '0x9mjwpc', 'cord19-fulltext_hash': '2419ba014f673040b6a3879c3473e9267eec28c9', 'journal': 'Clinical Microbiology and Infection', 'publish_time': '2014-03-31', 'source': 'Elsevier', 'title': 'Emerging respiratory viruses: is it ‘much ado about nothing’? (Shakespeare)', '_hash_id': '3023a4f64973996f328707734265bc3f', 'url': 'https://doi.org/10.1111/1469-0691.12488', 'bodytexts': ['2bbe6b5c0f010ab26760750d1500e872', '410a44abbda63b7ec6da59632e274287', 'e1020b049806d84befe1a951957b6e30', '1b53f789769037e5d480047a0063a94e', '701b55d2ebb05f4a7d3a309d453e1f2f', '1b66b3ec8a01ccf605f90088686729d9'], 'abstracts': []}}]

# %%
PID = pd.DataFrame(PaperID_to_Info)

# %%
PID
# Out:
#                                                     Info      MeSH
# 0      {'cord_uid': '0x9mjwpc', 'cord19-fulltext_hash...  0x9mjwpc
# 1      {'cord_uid': 'tyro2vuo', 'cord19-fulltext_hash...  tyro2vuo
# 2      {'cord_uid': 'gegboxgs', 'cord19-fulltext_hash...  gegboxgs
# 3      {'cord_uid': 'btdbv2tk', 'cord19-fulltext_hash...  btdbv2tk
# 4      {'cord_uid': 'eptit46j', 'cord19-fulltext_hash...  eptit46j
# 5      {'cord_uid': 'ejfp8gqz', 'cord19-fulltext_hash...  ejfp8gqz
# 6      {'cord_uid': 'waidnotv', 'cord19-fulltext_hash...  waidnotv
# 7      {'cord_uid': '7bmwfubu', 'journal': 'Bioscienc...  7bmwfubu
# 8      {'cord_uid': 'aim1fiaj', 'cord19-fulltext_hash...  aim1fiaj
# 9      {'cord_uid': 'f3zdttfo', 'cord19-fulltext_hash...  f3zdttfo
# 10     {'cord_uid': 'u4r84scm', 'cord19-fulltext_hash...  u4r84scm
# 11     {'cord_uid': 'uhrciaiz', 'cord19-fulltext_hash...  uhrciaiz
# 12     {'cord_uid': 'mc7pifep', 'cord19-fulltext_hash...  mc7pifep
# 13     {'cord_uid': 'xh3vtwy2', 'journal': 'BMC Proc'...  xh3vtwy2
# 14     {'cord_uid': 'm4jo053m', 'cord19-fulltext_hash...  m4jo053m
# 15     {'cord_uid': '404zraam', 'cord19-fulltext_hash...  404zraam
# 16     {'cord_uid': '2h197t8y', 'cord19-fulltext_hash...  2h197t8y
# 17     {'cord_uid': '98vmwrx1', 'cord19-fulltext_hash...  98vmwrx1
# 18     {'cord_uid': 'nxhto48t', 'cord19-fulltext_hash...  nxhto48t
# 19     {'cord_uid': 'pw4f8asc', 'cord19-fulltext_hash...  pw4f8asc
# 20     {'cord_uid': 'jesz6uij', 'cord19-fulltext_hash...  jesz6uij
# 21     {'cord_uid': 'giabjjnz', 'cord19-fulltext_hash...  giabjjnz
# 22     {'cord_uid': 'd0ccqrmu', 'cord19-fulltext_hash...  d0ccqrmu
# 23     {'cord_uid': 'wq7p3116', 'cord19-fulltext_hash...  wq7p3116
# 24     {'cord_uid': 'savdgy0u', 'cord19-fulltext_hash...  savdgy0u
# 25     {'cord_uid': 'di7at6mm', 'cord19-fulltext_hash...  di7at6mm
# 26     {'cord_uid': 't8h1f6s6', 'cord19-fulltext_hash...  t8h1f6s6
# 27     {'cord_uid': '9nmmu3pd', 'cord19-fulltext_hash...  9nmmu3pd
# 28     {'cord_uid': '8glsl2ka', 'cord19-fulltext_hash...  8glsl2ka
# 29     {'cord_uid': 'nl6wcoeq', 'cord19-fulltext_hash...  nl6wcoeq
# ...                                                  ...       ...
# 13327  {'cord_uid': 'atfe2avm', 'cord19-fulltext_hash...  atfe2avm
# 13328  {'cord_uid': 'z30fpvcq', 'cord19-fulltext_hash...  z30fpvcq
# 13329  {'cord_uid': '3nz3169p', 'cord19-fulltext_hash...  3nz3169p
# 13330  {'cord_uid': 'k0uo6k3t', 'cord19-fulltext_hash...  k0uo6k3t
# 13331  {'cord_uid': 'vf4et613', 'cord19-fulltext_hash...  vf4et613
# 13332  {'cord_uid': '5op2m7pu', 'cord19-fulltext_hash...  5op2m7pu
# 13333  {'cord_uid': 'nwnqc2ij', 'cord19-fulltext_hash...  nwnqc2ij
# 13334  {'cord_uid': 'zgdbvfi4', 'cord19-fulltext_hash...  zgdbvfi4
# 13335  {'cord_uid': 'ek7mfzrs', 'cord19-fulltext_hash...  ek7mfzrs
# 13336  {'cord_uid': 'sysl8yj6', 'cord19-fulltext_hash...  sysl8yj6
# 13337  {'cord_uid': 'vb0002nx', 'cord19-fulltext_hash...  vb0002nx
# 13338  {'cord_uid': '91z7b4j3', 'cord19-fulltext_hash...  91z7b4j3
# 13339  {'cord_uid': 'tahmgsas', 'cord19-fulltext_hash...  tahmgsas
# 13340  {'cord_uid': '784hdny3', 'cord19-fulltext_hash...  784hdny3
# 13341  {'cord_uid': 'idfivpbo', 'cord19-fulltext_hash...  idfivpbo
# 13342  {'cord_uid': 'ftz9190a', 'cord19-fulltext_hash...  ftz9190a
# 13343  {'cord_uid': 'seev8ggt', 'cord19-fulltext_hash...  seev8ggt
# 13344  {'cord_uid': '4ua0oqbz', 'cord19-fulltext_hash...  4ua0oqbz
# 13345  {'cord_uid': 'v3spbo5u', 'cord19-fulltext_hash...  v3spbo5u
# 13346  {'cord_uid': 'evyniq0v', 'cord19-fulltext_hash...  evyniq0v
# 13347  {'cord_uid': 'tquyi392', 'cord19-fulltext_hash...  tquyi392
# 13348  {'cord_uid': 'cl60qmu3', 'cord19-fulltext_hash...  cl60qmu3
# 13349  {'cord_uid': 's12mcitm', 'cord19-fulltext_hash...  s12mcitm
# 13350  {'cord_uid': 'nhrzc7tj', 'journal': 'Mens Sana...  nhrzc7tj
# 13351  {'cord_uid': 'auy0h9wc', 'cord19-fulltext_hash...  auy0h9wc
# 13352  {'cord_uid': 'sz38oecu', 'cord19-fulltext_hash...  sz38oecu
# 13353  {'cord_uid': 'wcpdiykp', 'cord19-fulltext_hash...  wcpdiykp
# 13354  {'cord_uid': 'tz2rpixt', 'cord19-fulltext_hash...  tz2rpixt
# 13355  {'cord_uid': 'z86ruwxe', 'cord19-fulltext_hash...  z86ruwxe
# 13356  {'cord_uid': 'bnlkukto', 'cord19-fulltext_hash...  bnlkukto
#
# [13357 rows x 2 columns]

# %%
PID = PID.set_index('MeSH')

# %%
PID
# Out:
#                                                        Info
# MeSH
# 0x9mjwpc  {'cord_uid': '0x9mjwpc', 'cord19-fulltext_hash...
# tyro2vuo  {'cord_uid': 'tyro2vuo', 'cord19-fulltext_hash...
# gegboxgs  {'cord_uid': 'gegboxgs', 'cord19-fulltext_hash...
# btdbv2tk  {'cord_uid': 'btdbv2tk', 'cord19-fulltext_hash...
# eptit46j  {'cord_uid': 'eptit46j', 'cord19-fulltext_hash...
# ejfp8gqz  {'cord_uid': 'ejfp8gqz', 'cord19-fulltext_hash...
# waidnotv  {'cord_uid': 'waidnotv', 'cord19-fulltext_hash...
# 7bmwfubu  {'cord_uid': '7bmwfubu', 'journal': 'Bioscienc...
# aim1fiaj  {'cord_uid': 'aim1fiaj', 'cord19-fulltext_hash...
# f3zdttfo  {'cord_uid': 'f3zdttfo', 'cord19-fulltext_hash...
# u4r84scm  {'cord_uid': 'u4r84scm', 'cord19-fulltext_hash...
# uhrciaiz  {'cord_uid': 'uhrciaiz', 'cord19-fulltext_hash...
# mc7pifep  {'cord_uid': 'mc7pifep', 'cord19-fulltext_hash...
# xh3vtwy2  {'cord_uid': 'xh3vtwy2', 'journal': 'BMC Proc'...
# m4jo053m  {'cord_uid': 'm4jo053m', 'cord19-fulltext_hash...
# 404zraam  {'cord_uid': '404zraam', 'cord19-fulltext_hash...
# 2h197t8y  {'cord_uid': '2h197t8y', 'cord19-fulltext_hash...
# 98vmwrx1  {'cord_uid': '98vmwrx1', 'cord19-fulltext_hash...
# nxhto48t  {'cord_uid': 'nxhto48t', 'cord19-fulltext_hash...
# pw4f8asc  {'cord_uid': 'pw4f8asc', 'cord19-fulltext_hash...
# jesz6uij  {'cord_uid': 'jesz6uij', 'cord19-fulltext_hash...
# giabjjnz  {'cord_uid': 'giabjjnz', 'cord19-fulltext_hash...
# d0ccqrmu  {'cord_uid': 'd0ccqrmu', 'cord19-fulltext_hash...
# wq7p3116  {'cord_uid': 'wq7p3116', 'cord19-fulltext_hash...
# savdgy0u  {'cord_uid': 'savdgy0u', 'cord19-fulltext_hash...
# di7at6mm  {'cord_uid': 'di7at6mm', 'cord19-fulltext_hash...
# t8h1f6s6  {'cord_uid': 't8h1f6s6', 'cord19-fulltext_hash...
# 9nmmu3pd  {'cord_uid': '9nmmu3pd', 'cord19-fulltext_hash...
# 8glsl2ka  {'cord_uid': '8glsl2ka', 'cord19-fulltext_hash...
# nl6wcoeq  {'cord_uid': 'nl6wcoeq', 'cord19-fulltext_hash...
# ...                                                     ...
# atfe2avm  {'cord_uid': 'atfe2avm', 'cord19-fulltext_hash...
# z30fpvcq  {'cord_uid': 'z30fpvcq', 'cord19-fulltext_hash...
# 3nz3169p  {'cord_uid': '3nz3169p', 'cord19-fulltext_hash...
# k0uo6k3t  {'cord_uid': 'k0uo6k3t', 'cord19-fulltext_hash...
# vf4et613  {'cord_uid': 'vf4et613', 'cord19-fulltext_hash...
# 5op2m7pu  {'cord_uid': '5op2m7pu', 'cord19-fulltext_hash...
# nwnqc2ij  {'cord_uid': 'nwnqc2ij', 'cord19-fulltext_hash...
# zgdbvfi4  {'cord_uid': 'zgdbvfi4', 'cord19-fulltext_hash...
# ek7mfzrs  {'cord_uid': 'ek7mfzrs', 'cord19-fulltext_hash...
# sysl8yj6  {'cord_uid': 'sysl8yj6', 'cord19-fulltext_hash...
# vb0002nx  {'cord_uid': 'vb0002nx', 'cord19-fulltext_hash...
# 91z7b4j3  {'cord_uid': '91z7b4j3', 'cord19-fulltext_hash...
# tahmgsas  {'cord_uid': 'tahmgsas', 'cord19-fulltext_hash...
# 784hdny3  {'cord_uid': '784hdny3', 'cord19-fulltext_hash...
# idfivpbo  {'cord_uid': 'idfivpbo', 'cord19-fulltext_hash...
# ftz9190a  {'cord_uid': 'ftz9190a', 'cord19-fulltext_hash...
# seev8ggt  {'cord_uid': 'seev8ggt', 'cord19-fulltext_hash...
# 4ua0oqbz  {'cord_uid': '4ua0oqbz', 'cord19-fulltext_hash...
# v3spbo5u  {'cord_uid': 'v3spbo5u', 'cord19-fulltext_hash...
# evyniq0v  {'cord_uid': 'evyniq0v', 'cord19-fulltext_hash...
# tquyi392  {'cord_uid': 'tquyi392', 'cord19-fulltext_hash...
# cl60qmu3  {'cord_uid': 'cl60qmu3', 'cord19-fulltext_hash...
# s12mcitm  {'cord_uid': 's12mcitm', 'cord19-fulltext_hash...
# nhrzc7tj  {'cord_uid': 'nhrzc7tj', 'journal': 'Mens Sana...
# auy0h9wc  {'cord_uid': 'auy0h9wc', 'cord19-fulltext_hash...
# sz38oecu  {'cord_uid': 'sz38oecu', 'cord19-fulltext_hash...
# wcpdiykp  {'cord_uid': 'wcpdiykp', 'cord19-fulltext_hash...
# tz2rpixt  {'cord_uid': 'tz2rpixt', 'cord19-fulltext_hash...
# z86ruwxe  {'cord_uid': 'z86ruwxe', 'cord19-fulltext_hash...
# bnlkukto  {'cord_uid': 'bnlkukto', 'cord19-fulltext_hash...
#
# [13357 rows x 1 columns]

# %%
DF.to_csv('corona_mesh_paper_info.csv')
